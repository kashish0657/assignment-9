# %% [markdown]
# 9th february

# %%
1:ans:-

class vechile:
    
    def __init__(self,name,speed,average):
        
        self.name=name
        self.speed=speed
        self.average=average
        
    class car(vechile):
        
        def seat_capacity(self,capacity):
            self.capacity=capacity
            
            return(self.capacity)
        
        
obj_car=car("CAR",180,60)

print("Name of vechile :-",obj_car.name)

print("seating Capacity :-",obj_caqr.seat_capacity(8))

# %%
2:ans:-

class vechile:
    
    def __init__(self,name,speed,average):
        
        self.name=name
        self.speed=speed
        self.average=average
        
    class car(vechile):
        
        def seat_capacity(self,capacity):
            self.capacity=capacity
            
            return(self.capacity)
        
        
obj_car=car("CAR",180,60)

print("Name of vechile :-",obj_car.name)

print("seating Capacity :-",obj_caqr.seat_capacity(8))

# %%
3:ans:-

#Multiple inheritance

Actually, Multiple inheritance is a type of inheritance in which a child class inherits from more than one parent class .

# Example

class father:
    
    def rahul_father(self):
        
        print("My name is rohan and my son name is rahul.")
        
class mother:
    
    def rohaan_mother(self):
        
        print("My name is ravina and my son name is rahul.")
        
class child(father , mother):
    
    def rahul(self):
        
        print("my name is rahul and my father name is rohan and my mothername is ravina.")
        
        
obj_child=child()

obj_child.rahul_father()
obj_child.rahul_mother()
obj_child.rahul()

# %%
4:ans:-

Actually , Getter and Setter are methods in python in which getter method that allows us to access an attribute
or private or protected attributes in a given class, while setter method that allows us to set a mutatethe value
of an attributes in given class


class check_getter_and_setter:                                             # creating a class
    
    def __init__(self , book_name , price):                                # assigning values
        
        self.book_name=book_name
        self._price=price
        
    @property
    def price_access(self):                                             
        
        return self._price
    
    @price_access.setter
    def price_update(self ,new_price):
        
        self._price=new price
        
        return self._price
    
obj=check_getter_and_setter("let us python",280)

print(obj.book_name)

obj.price_access

obj.price_update=265

obj.price_access

# %%
5:ans:-

Actually , method overriding is a feature of object oriented programming languages where the subclass or
child class can provide the program with specific characteristics or a specific implementation process
of data provided that are already defined in the parent class or superclass.
In simple word , method overriding in python is when you have two methods with the same name that each
perform different tasks . 



class test_overriding_parent:
    
    def class_details(self):
        
        print("i am in parent class")
        
class test_overloading_child(test_overriding__parent):
    
    def class_details(self):
        
        print("i am in achild class")
        
        
obj_overriding=test_overriding_child()

obj_overriding.class_details()
